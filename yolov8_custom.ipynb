# %% [markdown]
# <a href="https://colab.research.google.com/github/Phichit-lap/plants-train-dataset/blob/main/yolov8_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 110MB/s]
#
# 2023-09-18 00:54:49.843660: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-18 00:54:51.120666: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...
# 100% 104k/104k [00:00<00:00, 99.0MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 59.4ms
# Speed: 0.6ms pre-process, 59.4ms inference, 332.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
#  12345.v1i.yolov5pytorch.zip   IMG20210126111936.jpg   yolo8
#  Classroom		       Lab6_R0.pdf	       yolov8_custom.ipynb
# 'Colab Notebooks'	      'My Drive'	      'บทที่ 1-2.pdf'
#  data.zip		       total		       พจิตร-อารม.docx
#  IMG20210119160713.jpg	       Untitled0.ipynb	       พิจิตร-เหล่าสุวรรณ.pptx
# 'IMG20210126111936 (1).jpg'    Untitled1.ipynb
# 'IMG20210126111936 (2).jpg'    yolo555

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/data.zip
# Out:
# /content/datasets
# Archive:  /content/gdrive/MyDrive/data.zip
#    creating: data/
#    creating: data/imges/
#    creating: data/imges/train/
#   inflating: data/imges/train/2464_0.jpg
#   inflating: data/imges/train/2464_0.txt
#   inflating: data/imges/train/2466_0.jpg
#   inflating: data/imges/train/2466_0.txt
#   inflating: data/imges/train/2467_0.jpg
#   inflating: data/imges/train/2467_0.txt
#   inflating: data/imges/train/2468_0.jpg
#   inflating: data/imges/train/2468_0.txt
#   inflating: data/imges/train/2469_0.jpg
#   inflating: data/imges/train/2469_0.txt
#   inflating: data/imges/train/2470_0.jpg
#   inflating: data/imges/train/2470_0.txt
#   inflating: data/imges/train/2471_0.jpg
#   inflating: data/imges/train/2471_0.txt
#   inflating: data/imges/train/2472_0.jpg
#   inflating: data/imges/train/2472_0.txt
#   inflating: data/imges/train/2473_0.jpg
#   inflating: data/imges/train/2473_0.txt
#   inflating: data/imges/train/2474_0.jpg
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/data/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
